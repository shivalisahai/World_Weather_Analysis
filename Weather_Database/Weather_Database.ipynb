# %%
# Import the dependencies.
import pandas as pd
# import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 750

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description
                         })

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | le port
# Processing Record 3 of Set 1 | kodiak
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | tiksi
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | severo-kurilsk
# Processing Record 8 of Set 1 | barcelos
# Processing Record 9 of Set 1 | bredasdorp
# Processing Record 10 of Set 1 | northview
# Processing Record 11 of Set 1 | tasiilaq
# Processing Record 12 of Set 1 | hobart
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | arica
# Processing Record 15 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 1 | rosetown
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | christchurch
# Processing Record 19 of Set 1 | kruisfontein
# Processing Record 20 of Set 1 | sambava
# Processing Record 21 of Set 1 | savannah bight
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | belmopan
# Processing Record 24 of Set 1 | kaeo
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | port-gentil
# Processing Record 27 of Set 1 | pemangkat
# Processing Record 28 of Set 1 | oboyan
# Processing Record 29 of Set 1 | okhotsk
# Processing Record 30 of Set 1 | port keats
# Processing Record 31 of Set 1 | hasaki
# Processing Record 32 of Set 1 | tuatapere
# Processing Record 33 of Set 1 | airai
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | busselton
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | qaanaaq
# Processing Record 38 of Set 1 | hatillo
# Processing Record 39 of Set 1 | novoagansk
# Processing Record 40 of Set 1 | bogdanovich
# Processing Record 41 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 1 | hami
# Processing Record 43 of Set 1 | husavik
# Processing Record 44 of Set 1 | saint-augustin
# Processing Record 45 of Set 1 | clyde river
# Processing Record 46 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 1 | hokitika
# Processing Record 48 of Set 1 | colombo
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | rosa zarate
# Processing Record 2 of Set 2 | zeitz
# Processing Record 3 of Set 2 | bloemhof
# Processing Record 4 of Set 2 | saint-pierre
# Processing Record 5 of Set 2 | baykit
# Processing Record 6 of Set 2 | alice springs
# Processing Record 7 of Set 2 | hilo
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | constitucion
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | barrow
# Processing Record 13 of Set 2 | grandview
# Processing Record 14 of Set 2 | juneau
# Processing Record 15 of Set 2 | vicuna
# Processing Record 16 of Set 2 | nuuk
# Processing Record 17 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 2 | tuktoyaktuk
# Processing Record 19 of Set 2 | makokou
# Processing Record 20 of Set 2 | iwanai
# Processing Record 21 of Set 2 | vardo
# Processing Record 22 of Set 2 | yellowknife
# Processing Record 23 of Set 2 | vostok
# Processing Record 24 of Set 2 | bluff
# Processing Record 25 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | gangotri
# City not found. Skipping...
# Processing Record 28 of Set 2 | rodrigues alves
# Processing Record 29 of Set 2 | bambanglipuro
# Processing Record 30 of Set 2 | luang prabang
# Processing Record 31 of Set 2 | dali
# Processing Record 32 of Set 2 | north bend
# Processing Record 33 of Set 2 | ilulissat
# Processing Record 34 of Set 2 | santiago
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | beisfjord
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | damghan
# Processing Record 40 of Set 2 | ushibuka
# Processing Record 41 of Set 2 | muros
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | muroto
# Processing Record 45 of Set 2 | albany
# Processing Record 46 of Set 2 | thompson
# Processing Record 47 of Set 2 | muravlenko
# Processing Record 48 of Set 2 | lompoc
# Processing Record 49 of Set 2 | buchanan
# Processing Record 50 of Set 2 | cherskiy
# Processing Record 1 of Set 3 | brae
# Processing Record 2 of Set 3 | sibolga
# Processing Record 3 of Set 3 | denpasar
# Processing Record 4 of Set 3 | kapaa
# Processing Record 5 of Set 3 | rawson
# Processing Record 6 of Set 3 | victoria
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | trinidad
# Processing Record 9 of Set 3 | odda
# Processing Record 10 of Set 3 | miri
# Processing Record 11 of Set 3 | new norfolk
# Processing Record 12 of Set 3 | muhos
# Processing Record 13 of Set 3 | katsuura
# Processing Record 14 of Set 3 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 3 | zhaotong
# Processing Record 17 of Set 3 | hamilton
# Processing Record 18 of Set 3 | cape town
# Processing Record 19 of Set 3 | marquette
# Processing Record 20 of Set 3 | obo
# Processing Record 21 of Set 3 | luderitz
# Processing Record 22 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 23 of Set 3 | chokurdakh
# Processing Record 24 of Set 3 | khasan
# Processing Record 25 of Set 3 | ponta do sol
# Processing Record 26 of Set 3 | kaitangata
# Processing Record 27 of Set 3 | tilichiki
# Processing Record 28 of Set 3 | acara
# Processing Record 29 of Set 3 | rio claro
# Processing Record 30 of Set 3 | catende
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | esperance
# Processing Record 33 of Set 3 | port hardy
# Processing Record 34 of Set 3 | rupert
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | azul
# Processing Record 37 of Set 3 | phuket
# Processing Record 38 of Set 3 | aksarka
# Processing Record 39 of Set 3 | porto santo
# Processing Record 40 of Set 3 | atuona
# Processing Record 41 of Set 3 | qeshm
# Processing Record 42 of Set 3 | manzhouli
# Processing Record 43 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 3 | praia
# Processing Record 45 of Set 3 | saskylakh
# Processing Record 46 of Set 3 | hovd
# Processing Record 47 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 3 | flin flon
# Processing Record 49 of Set 3 | vanimo
# Processing Record 50 of Set 3 | hermanus
# Processing Record 1 of Set 4 | kholtoson
# Processing Record 2 of Set 4 | almeirim
# Processing Record 3 of Set 4 | fortuna
# Processing Record 4 of Set 4 | namatanai
# Processing Record 5 of Set 4 | cap malheureux
# Processing Record 6 of Set 4 | zhangjiakou
# Processing Record 7 of Set 4 | praya
# Processing Record 8 of Set 4 | marabba
# Processing Record 9 of Set 4 | jibuti
# Processing Record 10 of Set 4 | mayo
# Processing Record 11 of Set 4 | rocha
# Processing Record 12 of Set 4 | severnyy
# Processing Record 13 of Set 4 | srednekolymsk
# Processing Record 14 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 4 | mahebourg
# Processing Record 16 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 4 | huarmey
# Processing Record 18 of Set 4 | kutum
# Processing Record 19 of Set 4 | samarai
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | sakakah
# Processing Record 22 of Set 4 | bandarbeyla
# Processing Record 23 of Set 4 | male
# Processing Record 24 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 4 | valera
# Processing Record 27 of Set 4 | ancud
# Processing Record 28 of Set 4 | dicabisagan
# Processing Record 29 of Set 4 | claremore
# Processing Record 30 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 31 of Set 4 | caravelas
# Processing Record 32 of Set 4 | kenai
# Processing Record 33 of Set 4 | caldas novas
# Processing Record 34 of Set 4 | dudinka
# Processing Record 35 of Set 4 | khatanga
# Processing Record 36 of Set 4 | les cayes
# Processing Record 37 of Set 4 | abiy adi
# City not found. Skipping...
# Processing Record 38 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 4 | fare
# Processing Record 40 of Set 4 | ahipara
# Processing Record 41 of Set 4 | solnechnyy
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | leh
# Processing Record 44 of Set 4 | santa maria
# Processing Record 45 of Set 4 | zyryanka
# Processing Record 46 of Set 4 | cabo san lucas
# Processing Record 47 of Set 4 | provideniya
# Processing Record 48 of Set 4 | urucara
# Processing Record 49 of Set 4 | jupiter
# Processing Record 50 of Set 4 | comodoro rivadavia
# Processing Record 1 of Set 5 | talnakh
# Processing Record 2 of Set 5 | dikson
# Processing Record 3 of Set 5 | raudeberg
# Processing Record 4 of Set 5 | ostrovnoy
# Processing Record 5 of Set 5 | cururupu
# Processing Record 6 of Set 5 | bonthe
# Processing Record 7 of Set 5 | ternuvate
# Processing Record 8 of Set 5 | axim
# Processing Record 9 of Set 5 | bilibino
# Processing Record 10 of Set 5 | tocopilla
# Processing Record 11 of Set 5 | broome
# Processing Record 12 of Set 5 | camalu
# Processing Record 13 of Set 5 | mizpe ramon
# City not found. Skipping...
# Processing Record 14 of Set 5 | hambantota
# Processing Record 15 of Set 5 | faanui
# Processing Record 16 of Set 5 | ketchikan
# Processing Record 17 of Set 5 | aurdal
# Processing Record 18 of Set 5 | codrington
# Processing Record 19 of Set 5 | tateyama
# Processing Record 20 of Set 5 | kijang
# Processing Record 21 of Set 5 | podgorenskiy
# Processing Record 22 of Set 5 | pevek
# Processing Record 23 of Set 5 | roald
# Processing Record 24 of Set 5 | chapais
# Processing Record 25 of Set 5 | komsomolskiy
# Processing Record 26 of Set 5 | portland
# Processing Record 27 of Set 5 | canmore
# Processing Record 28 of Set 5 | egvekinot
# Processing Record 29 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 5 | saint george
# Processing Record 31 of Set 5 | bereda
# Processing Record 32 of Set 5 | cidreira
# Processing Record 33 of Set 5 | koungheul
# Processing Record 34 of Set 5 | kaniama
# Processing Record 35 of Set 5 | lata
# Processing Record 36 of Set 5 | arraial do cabo
# Processing Record 37 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 5 | kununurra
# Processing Record 39 of Set 5 | vestmannaeyjar
# Processing Record 40 of Set 5 | arnprior
# Processing Record 41 of Set 5 | eyl
# Processing Record 42 of Set 5 | norman wells
# Processing Record 43 of Set 5 | longyearbyen
# Processing Record 44 of Set 5 | upernavik
# Processing Record 45 of Set 5 | kella
# Processing Record 46 of Set 5 | abu samrah
# Processing Record 47 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 48 of Set 5 | banjar
# Processing Record 49 of Set 5 | mmabatho
# Processing Record 50 of Set 5 | deputatskiy
# Processing Record 1 of Set 6 | ambulu
# Processing Record 2 of Set 6 | biak
# Processing Record 3 of Set 6 | crowley
# Processing Record 4 of Set 6 | marzuq
# Processing Record 5 of Set 6 | doha
# Processing Record 6 of Set 6 | kurchum
# Processing Record 7 of Set 6 | mingaora
# Processing Record 8 of Set 6 | lagoa
# Processing Record 9 of Set 6 | santa ines
# Processing Record 10 of Set 6 | pisco
# Processing Record 11 of Set 6 | bahia blanca
# Processing Record 12 of Set 6 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 6 | pemba
# Processing Record 14 of Set 6 | lebu
# Processing Record 15 of Set 6 | asau
# Processing Record 16 of Set 6 | lampang
# Processing Record 17 of Set 6 | sioux lookout
# Processing Record 18 of Set 6 | itoman
# Processing Record 19 of Set 6 | naron
# Processing Record 20 of Set 6 | nemuro
# Processing Record 21 of Set 6 | whitehorse
# Processing Record 22 of Set 6 | harper
# Processing Record 23 of Set 6 | iqaluit
# Processing Record 24 of Set 6 | sitka
# Processing Record 25 of Set 6 | appingedam
# Processing Record 26 of Set 6 | cockburn town
# Processing Record 27 of Set 6 | usinsk
# Processing Record 28 of Set 6 | maragogi
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | bonavista
# Processing Record 31 of Set 6 | jalu
# Processing Record 32 of Set 6 | berezovyy
# Processing Record 33 of Set 6 | mastic beach
# Processing Record 34 of Set 6 | verkhniy lomov
# Processing Record 35 of Set 6 | staryy nadym
# Processing Record 36 of Set 6 | guhagar
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | magistralnyy
# Processing Record 39 of Set 6 | san cristobal
# Processing Record 40 of Set 6 | klaksvik
# Processing Record 41 of Set 6 | nikolskoye
# Processing Record 42 of Set 6 | cianorte
# Processing Record 43 of Set 6 | mlalo
# Processing Record 44 of Set 6 | bam
# Processing Record 45 of Set 6 | alofi
# Processing Record 46 of Set 6 | barcelona
# Processing Record 47 of Set 6 | kudahuvadhoo
# Processing Record 48 of Set 6 | shache
# Processing Record 49 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 50 of Set 6 | dahuk
# Processing Record 1 of Set 7 | mikuni
# Processing Record 2 of Set 7 | ulaangom
# Processing Record 3 of Set 7 | lawrenceburg
# Processing Record 4 of Set 7 | tazmalt
# Processing Record 5 of Set 7 | santa cruz
# Processing Record 6 of Set 7 | wellington
# Processing Record 7 of Set 7 | honningsvag
# Processing Record 8 of Set 7 | mormugao
# Processing Record 9 of Set 7 | meadow lake
# Processing Record 10 of Set 7 | bethel
# Processing Record 11 of Set 7 | salalah
# Processing Record 12 of Set 7 | miandrivazo
# Processing Record 13 of Set 7 | benghazi
# Processing Record 14 of Set 7 | lulea
# Processing Record 15 of Set 7 | normandin
# Processing Record 16 of Set 7 | schwedt
# Processing Record 17 of Set 7 | vila franca do campo
# Processing Record 18 of Set 7 | buraydah
# Processing Record 19 of Set 7 | saucillo
# Processing Record 20 of Set 7 | pogoanele
# Processing Record 21 of Set 7 | constantine
# Processing Record 22 of Set 7 | tessalit
# Processing Record 23 of Set 7 | opuwo
# Processing Record 24 of Set 7 | bourail
# Processing Record 25 of Set 7 | waingapu
# Processing Record 26 of Set 7 | singaparna
# Processing Record 27 of Set 7 | cotonou
# Processing Record 28 of Set 7 | dunedin
# Processing Record 29 of Set 7 | panama city
# Processing Record 30 of Set 7 | marienburg
# Processing Record 31 of Set 7 | khorixas
# Processing Record 32 of Set 7 | torbay
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | morro bay
# Processing Record 35 of Set 7 | kaili
# Processing Record 36 of Set 7 | la baule-escoublac
# Processing Record 37 of Set 7 | wattegama
# Processing Record 38 of Set 7 | madimba
# Processing Record 39 of Set 7 | pochutla
# Processing Record 40 of Set 7 | sibiti
# Processing Record 41 of Set 7 | ouallam
# Processing Record 42 of Set 7 | hirara
# Processing Record 43 of Set 7 | roseau
# Processing Record 44 of Set 7 | aranda de duero
# Processing Record 45 of Set 7 | atar
# Processing Record 46 of Set 7 | hay river
# Processing Record 47 of Set 7 | acapulco
# Processing Record 48 of Set 7 | fort nelson
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | ayagoz
# Processing Record 1 of Set 8 | liku
# Processing Record 2 of Set 8 | margate
# Processing Record 3 of Set 8 | berlevag
# Processing Record 4 of Set 8 | souillac
# Processing Record 5 of Set 8 | naze
# Processing Record 6 of Set 8 | teguise
# Processing Record 7 of Set 8 | pyapon
# Processing Record 8 of Set 8 | lichuan
# Processing Record 9 of Set 8 | requena
# Processing Record 10 of Set 8 | necochea
# Processing Record 11 of Set 8 | coihueco
# Processing Record 12 of Set 8 | havre-saint-pierre
# Processing Record 13 of Set 8 | hualmay
# Processing Record 14 of Set 8 | camacha
# Processing Record 15 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 16 of Set 8 | sal
# Processing Record 17 of Set 8 | puerto wilches
# Processing Record 18 of Set 8 | cabra
# Processing Record 19 of Set 8 | kholm
# Processing Record 20 of Set 8 | tura
# Processing Record 21 of Set 8 | wajima
# Processing Record 22 of Set 8 | shkotovo-26
# City not found. Skipping...
# Processing Record 23 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 24 of Set 8 | robertsport
# Processing Record 25 of Set 8 | saquarema
# Processing Record 26 of Set 8 | laredo
# Processing Record 27 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 8 | bilma
# Processing Record 29 of Set 8 | acajutla
# Processing Record 30 of Set 8 | faya
# Processing Record 31 of Set 8 | padilla
# Processing Record 32 of Set 8 | saint-joseph
# Processing Record 33 of Set 8 | kayerkan
# Processing Record 34 of Set 8 | pringsewu
# Processing Record 35 of Set 8 | sheridan
# Processing Record 36 of Set 8 | chuy
# Processing Record 37 of Set 8 | byron bay
# Processing Record 38 of Set 8 | abohar
# Processing Record 39 of Set 8 | geraldton
# Processing Record 40 of Set 8 | beatrice
# Processing Record 41 of Set 8 | suna
# Processing Record 42 of Set 8 | vestmanna
# Processing Record 43 of Set 8 | romny
# Processing Record 44 of Set 8 | marsa matruh
# Processing Record 45 of Set 8 | coquimbo
# Processing Record 46 of Set 8 | khani
# Processing Record 47 of Set 8 | sao joao da barra
# Processing Record 48 of Set 8 | kulhudhuffushi
# Processing Record 49 of Set 8 | basarabeasca
# Processing Record 50 of Set 8 | velikiy ustyug
# Processing Record 1 of Set 9 | laguna
# Processing Record 2 of Set 9 | catamarca
# Processing Record 3 of Set 9 | kahului
# Processing Record 4 of Set 9 | vila velha
# Processing Record 5 of Set 9 | youhao
# Processing Record 6 of Set 9 | naryan-mar
# Processing Record 7 of Set 9 | yinchuan
# Processing Record 8 of Set 9 | salinopolis
# Processing Record 9 of Set 9 | tostamaa
# City not found. Skipping...
# Processing Record 10 of Set 9 | san patricio
# Processing Record 11 of Set 9 | beaverlodge
# Processing Record 12 of Set 9 | roebourne
# Processing Record 13 of Set 9 | pacific grove
# Processing Record 14 of Set 9 | umm lajj
# Processing Record 15 of Set 9 | sampit
# Processing Record 16 of Set 9 | baculin
# Processing Record 17 of Set 9 | konstantinovka
# Processing Record 18 of Set 9 | auki
# Processing Record 19 of Set 9 | nhulunbuy
# Processing Record 20 of Set 9 | mazagao
# Processing Record 21 of Set 9 | borovoy
# Processing Record 22 of Set 9 | port macquarie
# Processing Record 23 of Set 9 | sal rei
# Processing Record 24 of Set 9 | praia da vitoria
# Processing Record 25 of Set 9 | vagur
# Processing Record 26 of Set 9 | nanortalik
# Processing Record 27 of Set 9 | padang
# Processing Record 28 of Set 9 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | san jeronimo
# Processing Record 30 of Set 9 | dingle
# Processing Record 31 of Set 9 | katobu
# Processing Record 32 of Set 9 | saldanha
# Processing Record 33 of Set 9 | cucutilla
# Processing Record 34 of Set 9 | evensk
# Processing Record 35 of Set 9 | gizo
# Processing Record 36 of Set 9 | ferrol
# Processing Record 37 of Set 9 | sakit
# Processing Record 38 of Set 9 | sochi
# Processing Record 39 of Set 9 | northport
# Processing Record 40 of Set 9 | kiunga
# Processing Record 41 of Set 9 | kerch
# Processing Record 42 of Set 9 | balud
# Processing Record 43 of Set 9 | mercedes
# Processing Record 44 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 46 of Set 9 | tlalchapa
# Processing Record 47 of Set 9 | tamalin
# Processing Record 48 of Set 9 | verkhoyansk
# Processing Record 49 of Set 9 | veraval
# Processing Record 50 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 1 of Set 10 | maldonado
# Processing Record 2 of Set 10 | quatre cocos
# Processing Record 3 of Set 10 | aktau
# Processing Record 4 of Set 10 | pangnirtung
# Processing Record 5 of Set 10 | ginda
# Processing Record 6 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 7 of Set 10 | rochegda
# Processing Record 8 of Set 10 | ponta delgada
# Processing Record 9 of Set 10 | sapao
# City not found. Skipping...
# Processing Record 10 of Set 10 | noumea
# Processing Record 11 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 10 | coihaique
# Processing Record 13 of Set 10 | marion
# Processing Record 14 of Set 10 | stornoway
# Processing Record 15 of Set 10 | el monte
# Processing Record 16 of Set 10 | lima
# Processing Record 17 of Set 10 | wanaka
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | gogaran
# Processing Record 20 of Set 10 | karasburg
# Processing Record 21 of Set 10 | nidzica
# Processing Record 22 of Set 10 | hobyo
# Processing Record 23 of Set 10 | tete
# Processing Record 24 of Set 10 | kapasan
# Processing Record 25 of Set 10 | henties bay
# Processing Record 26 of Set 10 | krasnokamensk
# Processing Record 27 of Set 10 | banda aceh
# Processing Record 28 of Set 10 | zlatoust
# Processing Record 29 of Set 10 | mpika
# Processing Record 30 of Set 10 | olafsvik
# Processing Record 31 of Set 10 | deli tua
# Processing Record 32 of Set 10 | lauria
# Processing Record 33 of Set 10 | bairiki
# Processing Record 34 of Set 10 | mangan
# Processing Record 35 of Set 10 | narsaq
# Processing Record 36 of Set 10 | oistins
# Processing Record 37 of Set 10 | kachiry
# Processing Record 38 of Set 10 | flinders
# Processing Record 39 of Set 10 | touros
# Processing Record 40 of Set 10 | bantry
# Processing Record 41 of Set 10 | anadyr
# Processing Record 42 of Set 10 | corrente
# Processing Record 43 of Set 10 | qaqortoq
# Processing Record 44 of Set 10 | mount isa
# Processing Record 45 of Set 10 | staunton
# Processing Record 46 of Set 10 | chicama
# Processing Record 47 of Set 10 | port hedland
# Processing Record 48 of Set 10 | sao jose da coroa grande
# Processing Record 49 of Set 10 | bengkulu
# Processing Record 50 of Set 10 | forest grove
# Processing Record 1 of Set 11 | khawhai
# Processing Record 2 of Set 11 | san rafael
# Processing Record 3 of Set 11 | chardara
# Processing Record 4 of Set 11 | los llanos de aridane
# Processing Record 5 of Set 11 | rundu
# Processing Record 6 of Set 11 | paciran
# Processing Record 7 of Set 11 | perth
# Processing Record 8 of Set 11 | wexford
# Processing Record 9 of Set 11 | mahon
# Processing Record 10 of Set 11 | ambilobe
# Processing Record 11 of Set 11 | half moon bay
# Processing Record 12 of Set 11 | moron
# Processing Record 13 of Set 11 | kieta
# Processing Record 14 of Set 11 | zhigansk
# Processing Record 15 of Set 11 | westport
# Processing Record 16 of Set 11 | pundaguitan
# Processing Record 17 of Set 11 | tamuin
# Processing Record 18 of Set 11 | iquique
# Processing Record 19 of Set 11 | sataua
# City not found. Skipping...
# Processing Record 20 of Set 11 | sur
# Processing Record 21 of Set 11 | atasu
# Processing Record 22 of Set 11 | mandalgovi
# Processing Record 23 of Set 11 | lusambo
# Processing Record 24 of Set 11 | dalvik
# Processing Record 25 of Set 11 | aasiaat
# Processing Record 26 of Set 11 | varzea alegre
# Processing Record 27 of Set 11 | novyy urgal
# Processing Record 28 of Set 11 | buala
# Processing Record 29 of Set 11 | cuamba
# Processing Record 30 of Set 11 | teahupoo
# Processing Record 31 of Set 11 | san andres
# Processing Record 32 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 33 of Set 11 | sao filipe
# Processing Record 34 of Set 11 | mayumba
# Processing Record 35 of Set 11 | vejle
# Processing Record 36 of Set 11 | alexandria
# Processing Record 37 of Set 11 | araouane
# Processing Record 38 of Set 11 | akonolinga
# Processing Record 39 of Set 11 | beringovskiy
# Processing Record 40 of Set 11 | nakamura
# Processing Record 41 of Set 11 | kiama
# Processing Record 42 of Set 11 | skibbereen
# Processing Record 43 of Set 11 | la palma
# Processing Record 44 of Set 11 | shelui
# Processing Record 45 of Set 11 | carlagan
# Processing Record 46 of Set 11 | grand island
# Processing Record 47 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 11 | biltine
# Processing Record 49 of Set 11 | salta
# Processing Record 50 of Set 11 | santander
# Processing Record 1 of Set 12 | visnes
# Processing Record 2 of Set 12 | rafaela
# Processing Record 3 of Set 12 | zigong
# Processing Record 4 of Set 12 | haines junction
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | aracruz
# Processing Record 7 of Set 12 | charters towers
# Processing Record 8 of Set 12 | pimenta bueno
# Processing Record 9 of Set 12 | lekoni
# Processing Record 10 of Set 12 | kavaratti
# Processing Record 11 of Set 12 | lembeni
# Processing Record 12 of Set 12 | strezhevoy
# Processing Record 13 of Set 12 | lincoln
# Processing Record 14 of Set 12 | taguatinga
# Processing Record 15 of Set 12 | kolar
# Processing Record 16 of Set 12 | falun
# Processing Record 17 of Set 12 | kawana waters
# City not found. Skipping...
# Processing Record 18 of Set 12 | eberndorf
# Processing Record 19 of Set 12 | lagunas
# Processing Record 20 of Set 12 | micheweni
# Processing Record 21 of Set 12 | edgewater
# Processing Record 22 of Set 12 | west wendover
# Processing Record 23 of Set 12 | dzerzhinsk
# Processing Record 24 of Set 12 | tianpeng
# Processing Record 25 of Set 12 | ratangarh
# Processing Record 26 of Set 12 | dese
# Processing Record 27 of Set 12 | sandovo
# Processing Record 28 of Set 12 | jinotepe
# Processing Record 29 of Set 12 | yumen
# Processing Record 30 of Set 12 | meulaboh
# Processing Record 31 of Set 12 | mogzon
# Processing Record 32 of Set 12 | tekkali
# Processing Record 33 of Set 12 | broken hill
# Processing Record 34 of Set 12 | kirakira
# Processing Record 35 of Set 12 | belaya gora
# Processing Record 36 of Set 12 | taksimo
# Processing Record 37 of Set 12 | altay
# Processing Record 38 of Set 12 | tual
# Processing Record 39 of Set 12 | coatesville
# Processing Record 40 of Set 12 | tanout
# Processing Record 41 of Set 12 | mbinga
# Processing Record 42 of Set 12 | groa
# Processing Record 43 of Set 12 | kushiro
# Processing Record 44 of Set 12 | tromso
# Processing Record 45 of Set 12 | warri
# Processing Record 46 of Set 12 | pangai
# Processing Record 47 of Set 12 | golden
# Processing Record 48 of Set 12 | santana do acarau
# Processing Record 49 of Set 12 | baranain
# Processing Record 50 of Set 12 | port lincoln
# Processing Record 1 of Set 13 | purworejo
# Processing Record 2 of Set 13 | la ciotat
# Processing Record 3 of Set 13 | vila
# Processing Record 4 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 13 | mandan
# Processing Record 6 of Set 13 | santa isabel do rio negro
# Processing Record 7 of Set 13 | freeport
# Processing Record 8 of Set 13 | mount gambier
# Processing Record 9 of Set 13 | lafiagi
# Processing Record 10 of Set 13 | viedma
# Processing Record 11 of Set 13 | grants
# Processing Record 12 of Set 13 | abu dhabi
# Processing Record 13 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 14 of Set 13 | ozu
# Processing Record 15 of Set 13 | thinadhoo
# Processing Record 16 of Set 13 | karlsfeld
# Processing Record 17 of Set 13 | garachine
# Processing Record 18 of Set 13 | manggar
# Processing Record 19 of Set 13 | la ronge
# Processing Record 20 of Set 13 | kalmunai
# Processing Record 21 of Set 13 | saint anthony
# Processing Record 22 of Set 13 | guangshui
# Processing Record 23 of Set 13 | vao
# Processing Record 24 of Set 13 | shebunino
# Processing Record 25 of Set 13 | suez
# Processing Record 26 of Set 13 | vila nova de milfontes
# Processing Record 27 of Set 13 | labuhan
# Processing Record 28 of Set 13 | leningradskiy
# Processing Record 29 of Set 13 | bathsheba
# Processing Record 30 of Set 13 | arman
# Processing Record 31 of Set 13 | baikunthpur
# Processing Record 32 of Set 13 | bull savanna
# Processing Record 33 of Set 13 | ucluelet
# Processing Record 34 of Set 13 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 35 of Set 13 | ust-karsk
# Processing Record 36 of Set 13 | suhbaatar
# Processing Record 37 of Set 13 | mahajanga
# Processing Record 38 of Set 13 | karratha
# Processing Record 39 of Set 13 | aklavik
# Processing Record 40 of Set 13 | dangtu
# Processing Record 41 of Set 13 | mitsamiouli
# Processing Record 42 of Set 13 | leshukonskoye
# Processing Record 43 of Set 13 | fukue
# Processing Record 44 of Set 13 | lerwick
# Processing Record 45 of Set 13 | voitsberg
# Processing Record 46 of Set 13 | nador
# Processing Record 47 of Set 13 | mega
# Processing Record 48 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 13 | corinto
# Processing Record 50 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 14 | karema
# Processing Record 2 of Set 14 | lubango
# Processing Record 3 of Set 14 | nabire
# Processing Record 4 of Set 14 | igarka
# Processing Record 5 of Set 14 | bafia
# Processing Record 6 of Set 14 | san angelo
# Processing Record 7 of Set 14 | altamira
# Processing Record 8 of Set 14 | yanan
# City not found. Skipping...
# Processing Record 9 of Set 14 | sturgeon bay
# Processing Record 10 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 11 of Set 14 | jumla
# Processing Record 12 of Set 14 | quelimane
# Processing Record 13 of Set 14 | swift current
# Processing Record 14 of Set 14 | oussouye
# Processing Record 15 of Set 14 | cloquet
# Processing Record 16 of Set 14 | icod de los vinos
# Processing Record 17 of Set 14 | pasni
# Processing Record 18 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 19 of Set 14 | umm kaddadah
# Processing Record 20 of Set 14 | mackay
# Processing Record 21 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 14 | kwinana
# Processing Record 23 of Set 14 | bunia
# Processing Record 24 of Set 14 | kibala
# Processing Record 25 of Set 14 | miranda
# Processing Record 26 of Set 14 | bardiyah
# Processing Record 27 of Set 14 | oskarshamn
# Processing Record 28 of Set 14 | porbandar
# Processing Record 29 of Set 14 | tongren
# Processing Record 30 of Set 14 | arlit
# Processing Record 31 of Set 14 | yar-sale
# Processing Record 32 of Set 14 | tabou
# Processing Record 33 of Set 14 | moree
# Processing Record 34 of Set 14 | jamsa
# Processing Record 35 of Set 14 | ugoofaaru
# Processing Record 36 of Set 14 | cadillac
# Processing Record 37 of Set 14 | nakusp
# Processing Record 38 of Set 14 | launceston
# Processing Record 39 of Set 14 | lat yao
# Processing Record 40 of Set 14 | biala podlaska
# Processing Record 41 of Set 14 | remanso
# Processing Record 42 of Set 14 | tondano
# Processing Record 43 of Set 14 | tommot
# Processing Record 44 of Set 14 | tsiroanomandidy
# Processing Record 45 of Set 14 | udachnyy
# Processing Record 46 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 47 of Set 14 | los alamos
# Processing Record 48 of Set 14 | lom sak
# Processing Record 49 of Set 14 | pitanga
# Processing Record 50 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 1 of Set 15 | hofn
# Processing Record 2 of Set 15 | bacolod
# Processing Record 3 of Set 15 | saiha
# Processing Record 4 of Set 15 | mackenzie
# Processing Record 5 of Set 15 | mafra
# Processing Record 6 of Set 15 | san antonio
# Processing Record 7 of Set 15 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 15 | rexburg
# Processing Record 9 of Set 15 | naranjos
# Processing Record 10 of Set 15 | shimoda
# Processing Record 11 of Set 15 | belle glade
# Processing Record 12 of Set 15 | san-pedro
# Processing Record 13 of Set 15 | bandipur
# Processing Record 14 of Set 15 | aykhal
# Processing Record 15 of Set 15 | dzilam gonzalez
# Processing Record 16 of Set 15 | dickinson
# Processing Record 17 of Set 15 | luena
# Processing Record 18 of Set 15 | bollnas
# Processing Record 19 of Set 15 | svetlaya
# Processing Record 20 of Set 15 | san ramon
# Processing Record 21 of Set 15 | winnemucca
# Processing Record 22 of Set 15 | hondo
# Processing Record 23 of Set 15 | isangel
# Processing Record 24 of Set 15 | korem
# Processing Record 25 of Set 15 | sainte-marie
# Processing Record 26 of Set 15 | puerto leguizamo
# Processing Record 27 of Set 15 | wad rawah
# Processing Record 28 of Set 15 | west point
# Processing Record 29 of Set 15 | kikwit
# Processing Record 30 of Set 15 | amapa
# Processing Record 31 of Set 15 | iralaya
# Processing Record 32 of Set 15 | qasigiannguit
# Processing Record 33 of Set 15 | motala
# Processing Record 34 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 35 of Set 15 | port moresby
# Processing Record 36 of Set 15 | paita
# Processing Record 37 of Set 15 | esso
# Processing Record 38 of Set 15 | bairnsdale
# Processing Record 39 of Set 15 | santa rosa
# Processing Record 40 of Set 15 | tautira
# Processing Record 41 of Set 15 | maihar
# Processing Record 42 of Set 15 | bo phloi
# Processing Record 43 of Set 15 | san quintin
# Processing Record 44 of Set 15 | lavrentiya
# Processing Record 45 of Set 15 | chapleau
# Processing Record 46 of Set 15 | mabaruma
# Processing Record 47 of Set 15 | lorengau
# Processing Record 48 of Set 15 | bonfim
# Processing Record 49 of Set 15 | tahta
# Processing Record 50 of Set 15 | sosnovo-ozerskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Le Port      RE -20.9373   55.2919     67.24        71           4
# 1          Kodiak      US  57.7900 -152.4072     51.31        82         100
# 2    Punta Arenas      CL -53.1500  -70.9167     35.71        87          20
# 3           Tiksi      RU  71.6872  128.8694     34.70        76         100
# 4      Butaritari      KI   3.0707  172.7902     81.81        77          83
# 5  Severo-Kurilsk      RU  50.6789  156.1250     47.86        94         100
# 6        Barcelos      PT  41.5388   -8.6151     60.91        86          52
# 7      Bredasdorp      ZA -34.5322   20.0403     49.21        85          10
# 8       Northview      US  43.0456  -85.6006     77.86        44          75
# 9        Tasiilaq      GL  65.6145  -37.6368     44.76        68          64
#
#    Wind Speed Current Description
# 0        3.33          light rain
# 1       12.66     overcast clouds
# 2       19.57          few clouds
# 3       17.54     overcast clouds
# 4       14.63          light rain
# 5        1.25     overcast clouds
# 6        7.25       broken clouds
# 7        3.60           clear sky
# 8        8.05       broken clouds
# 9        4.14       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index="City_ID")
